# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# import required files

# %%
df = pd.read_csv('Diwali Sales Data.csv', encoding='unicode_escape')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0  \
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders
# 0     Maharashtra   Western       Healthcare             Auto       1  \
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#drop columns doesn't have any data
df.drop(['Status','unnamed1'], axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
#remove all rows having NA's
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
df.dtypes
# Out:
# User_ID               int64
# Cust_name            object
# Product_ID           object
# Gender               object
# Age Group            object
# Age                   int64
# Marital_Status        int64
# State                object
# Zone                 object
# Occupation           object
# Product_Category     object
# Orders                int64
# Amount              float64
# dtype: object

# %%
df['Amount']=df['Amount'].astype('int32')
df.dtypes
# Out:
# User_ID              int64
# Cust_name           object
# Product_ID          object
# Gender              object
# Age Group           object
# Age                  int64
# Marital_Status       int64
# State               object
# Zone                object
# Occupation          object
# Product_Category    object
# Orders               int64
# Amount               int32
# dtype: object

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# ## Data Analysis with Visualization

# %% [markdown]
# ### Gender

# %%
#plot bar chart to indentify Male, Female Count
plot = sns.countplot(x='Gender', data=df)
for bars in plot.containers:
    plot.bar_label(bars)

# %%
gender_wise_sale = df.groupby('Gender', as_index=False).sum().sort_values(by='Amount', ascending=True)
sns.barplot(x='Gender',y='Amount',data=gender_wise_sale)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# Notes: From above analysis wrt "Gender", I have observed that Number of orders and purchasing power is higher for Female customers

# %% [markdown]
# ### Age

# %%
#find out agewise number of orders being placed for male, female
age_plot = sns.countplot(x='Age Group',data=df, hue='Gender')
for bar in age_plot.containers:
    age_plot.bar_label(bar)

# %%
#total amount wrt age group
age_group_wise_data = df.groupby(by='Age Group', as_index=False).sum().sort_values(by='Amount',ascending=False)
sns.barplot(data=age_group_wise_data, x='Age Group',y='Amount')
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# Notes: from above analysis wrt Age, I have observed that highest number of orders being placed by Femals having age between 26 and 35

# %% [markdown]
# ### Occupation

# %%
sns.set(rc={'figure.figsize':(20,5)})
occupation_plot = sns.countplot(data=df, x='Occupation')
for bar in occupation_plot.containers:
    occupation_plot.bar_label(bar)

# %%
occupation_wise_value = df.groupby(['Occupation'], as_index=False).sum().sort_values(by='Amount',ascending=False)
sns.barplot(data=occupation_wise_value, x='Occupation',y='Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# Based on above charts we have found that highest number of orders and order amount were from people working in IT sector.

# %% [markdown]
# # State

# %%
sns.set(rc={'figure.figsize':(25,5)})
state_plot = sns.countplot(data=df, 
                           x='State', 
                           order=df['State'].value_counts().index)
for bar in state_plot.containers:
    state_plot.bar_label(bar)

# %%
state_wise_orders = df.groupby(['State'], as_index=False).sum().sort_values(by='Orders', ascending=False)
state_plot = sns.barplot(data=state_wise_orders, x='State', y='Orders')

for bar in state_plot.containers:
    state_plot.bar_label(bar)

# %%
state_wise_value = df.groupby(['State'], as_index=False).sum().sort_values(by='Amount', ascending=False)
state_plot = sns.barplot(data=state_wise_value, x='State', y='Amount')

for bar in state_plot.containers:
    state_plot.bar_label(bar)

# %% [markdown]
# From above chart analysis we can see that highest number of orders being ordered from the people residing in Uttar Pradesh state and less number of orders being ordered from Telengana state.

# %% [markdown]
# # Category

# %%
category_wise_data = df.groupby(['Product_Category'], as_index=False).sum().sort_values(by='Orders', ascending=False).head(10)
category_plot = sns.barplot(data=category_wise_data, x='Product_Category', y='Orders')
for bar in category_plot.containers:
    category_plot.bar_label(bar)

# %%
category_wise_data = df.groupby(['Product_Category'], as_index=False).sum().sort_values(by='Amount', ascending=False).head(10)
category_plot = sns.barplot(data=category_wise_data, x='Product_Category', y='Amount')
for bar in category_plot.containers:
    category_plot.bar_label(bar)

# %% [markdown]
# From above graph analysis we can observe that highest number of orders are placed for "Clothing & Apparel" Category but Total Order Amount is higher for "Food" Category.

# %% [markdown]
# # Conclusion:
# ### Female belongs to age grop 26-35 residing in Uttarpradesh, Maharashtra and Karnataka states having occupation in It, Healthcare and Aviation are more likely to Food, Apparel and Electronics.
